# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_json("./BANKNIFTY18AUG0228100CE.json")

# %%
df['date'] = pd.to_datetime(df['t'],unit='s')
df['date'] = df['date'].dt.tz_localize('utc').dt.tz_convert('Asia/kolkata')
df['date'] = df['date'].dt.tz_localize(None)

# %%
print(df["date"])
# Out:
# 0     2018-08-02 09:15:59
# 1     2018-08-02 09:16:59
# 2     2018-08-02 09:17:59
# 3     2018-08-02 09:18:59
# 4     2018-08-02 09:19:59
#               ...
# 370   2018-08-02 15:25:59
# 371   2018-08-02 15:26:59
# 372   2018-08-02 15:27:59
# 373   2018-08-02 15:28:59
# 374   2018-08-02 15:29:59
# Name: date, Length: 375, dtype: datetime64[ns]
