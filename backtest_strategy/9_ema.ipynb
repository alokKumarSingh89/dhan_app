# %%
import pandas as pd

# %%
def proccess(data):
    if data["tranaction_type"] == "Sell":
        data["pnl"] = ((data["entry"] - data["exit"])/data["entry"])*100
    else:
        data["pnl"] = ((-data["entry"] + data["exit"])/data["entry"])*100
    return data

# %%
def run():
    dict_data = {"script":[],"date":[],"pnl":[]}
    for sy in ["BAJFINANCE"]:
        for year in range(2019,2025):
            df = pd.read_csv(f"backtest/9_ema/{year}-{sy}.csv")
            # df = df[df['date']<df['exit_time']]
            df = df.apply(proccess,axis=1)
            df2=df.dropna(axis=0)
            print(year)
            sum = df2["pnl"].sum(axis=0)
            dict_data["date"].append(year)
            dict_data["script"].append(sy)
            dict_data["pnl"].append((sum/df2["entry"].iloc[0])*100)
    return pd.DataFrame(dict_data)

# %%
df = run()
# df.sort_values(by='pnl',ascending=False)
df
# Out:
# 2019
# 2020
# 2021
# 2022
# 2023
# 2024
#   script  date       pnl
# 0   LTIM  2019 -0.394395
# 1   LTIM  2020 -0.364033
# 2   LTIM  2021 -0.323307
# 3   LTIM  2022 -0.489491
# 4   LTIM  2023 -0.350718
# 5   LTIM  2024 -0.415738

# %%
df = pd.read_csv(f"strategy_list/2024-BAJFINANCE.csv")
df = df.apply(proccess,axis=1)
df.drop(columns=["Unnamed: 0"], axis=1)
df["date"] = df["entry_time"].apply(lambda x : x.split(" ")[0])
df["month"] = df["date"].apply(lambda x : x.split("-")[1])
df.groupby(["month"])["pnl"].sum()
# Out:
# month
# 01   -0.943720
# 02   -2.811495
# 03   -6.687285
# Name: pnl, dtype: float64

# %%
df = pd.read_csv(f"strategy_list/2024-BAJFINANCE.csv")
df = df.apply(proccess,axis=1)
df.drop(columns=["Unnamed: 0"], axis=1)
df["date"] = df["entry_time"].apply(lambda x : x.split(" ")[0])
df["month"] = df["date"].apply(lambda x : x.split("-")[1])
df.groupby(["month"])["pnl"].sum()
# Out:
# month
# 04    3.107526
# 05    7.357994
# 06   -1.533511
# 07   -0.593059
# Name: pnl, dtype: float64

# %%
def performance():
    data = {
        "month":[],
        "year":[],
        "pnl":[],
    }
    df_year = None
    for year in range(2024,2025):
        for month in range(1,13):
            try:
                df = pd.read_csv(f"strategy_list/9_ema/INDUSINDBK-5-{month}-{year}.csv")
                df.drop(columns=["Unnamed: 0"], axis=1)
                df["date"] = df["entry_time"].apply(lambda x : x.split(" ")[0])
                df["month"] = df["date"].apply(lambda x : x.split("-")[1])
                df["day"] = df["date"].apply(lambda x : x.split("-")[2])
                # new_df = df[df["day"]=="01"]
                data["month"].append(month)
                data["year"].append(year)
                data["pnl"].append(df.groupby(["month"])["pnl"].sum().values[0])
            except Exception as e:
                print(e)
    df = pd.DataFrame(data)
    df.set_index("year", inplace=True)
    return df

#

# %%
df = performance()
# Out:
# 'entry_time'
# 'entry_time'
# 'entry_time'
# 'entry_time'

# %%
df.sort_values("pnl", ascending=False)
# Out:
#       month    pnl
# year
# 2024      6  31.48
# 2024      7  27.63
# 2024      4  26.67
# 2024      3  25.23
# 2024      5  24.74
# 2024      2  21.53
# 2024      1  19.67
# 2024      8   8.36

# %%
# Out:
#     month  year     pnl
# 46     11  2023    8.41
# 55      8  2024    8.64
# 45     10  2023   11.75
# 39      4  2023   11.81
# 41      6  2023   13.27
# 34     11  2022   15.13
# 43      8  2023   15.52
# 44      9  2023   15.86
# 50      3  2024   16.78
# 40      5  2023   17.53
# 27      4  2022   17.81
# 30      7  2022   18.57
# 47     12  2023   18.88
# 18      7  2021   19.07
# 33     10  2022   19.47
# 48      1  2024   19.59
# 29      6  2022   19.76
# 31      8  2022   19.81
# 51      4  2024   20.18
# 9      10  2020   20.49
# 35     12  2022   20.55
# 20      9  2021   21.49
# 37      2  2023   21.50
# 0       1  2020   21.75
# 54      7  2024   21.79
# 17      6  2021   24.28
# 36      1  2023   24.41
# 42      7  2023   24.55
# 23     12  2021   25.21
# 7       8  2020   26.01
# 19      8  2021   26.08
# 38      3  2023   26.90
# 32      9  2022   26.98
# 52      5  2024   27.31
# 24      1  2022   27.68
# 8       9  2020   28.02
# 16      5  2021   29.42
# ...
