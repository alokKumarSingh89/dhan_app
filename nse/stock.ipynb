# %%
import requests, time, hmac, base64, struct
from fyers_apiv3 import fyersModel
from urllib.parse import urlparse, parse_qs
import os
import pandas as pd
from database.db import db

# %%
data = [item for item in db["NSE:SBIN-EQ"].find()]

# %%
data
# Out:
# [{'_id': ObjectId('669cbabbe3eaf656bbbf8327'),
#   'datetime': datetime.datetime(2024, 7, 19, 9, 15),
#   'open': 895.0,
#   'high': 895.0,
#   'low': 888.0,
#   'close': 889.0,
#   'volumen': 569476},
#  {'_id': ObjectId('669cbabbe3eaf656bbbf8328'),
#   'datetime': datetime.datetime(2024, 7, 19, 9, 20),
#   'open': 888.85,
#   'high': 890.5,
#   'low': 885.8,
#   'close': 889.9,
#   'volumen': 421069},
#  {'_id': ObjectId('669cbabbe3eaf656bbbf8329'),
#   'datetime': datetime.datetime(2024, 7, 19, 9, 25),
#   'open': 889.65,
#   'high': 894.0,
#   'low': 889.4,
#   'close': 894.0,
#   'volumen': 358392},
#  {'_id': ObjectId('669cbabbe3eaf656bbbf832a'),
#   'datetime': datetime.datetime(2024, 7, 19, 9, 30),
#   'open': 894.15,
#   'high': 895.0,
#   'low': 891.95,
#   'close': 892.95,
#   'volumen': 245670},
#  {'_id': ObjectId('669cbabbe3eaf656bbbf832b'),
#   'datetime': datetime.datetime(2024, 7, 19, 9, 35),
#   'open': 892.75,
#   'high': 893.45,
#   'low': 891.3,
# ...

# %%
# 2024, 7, 19, 9, 30
db["NSE:SBIN-EQ"].find_one({'datetime': pd.Timestamp(year=2024,month=7, day=19,hour=9,minute=30)})
# Out:
# {'_id': ObjectId('669cbabbe3eaf656bbbf832a'),
#  'datetime': datetime.datetime(2024, 7, 19, 9, 30),
#  'open': 894.15,
#  'high': 895.0,
#  'low': 891.95,
#  'close': 892.95,
#  'volumen': 245670}
